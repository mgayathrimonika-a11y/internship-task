# %% [markdown]
# <a href="https://colab.research.google.com/github/mgayathrimonika-a11y/internship-task/blob/main/tak_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Titanic dataset URL
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

# Load dataset from URL
df = pd.read_csv(url)

# Verify data
print(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Data types
print("\nData Types:")
print(df.dtypes)

# Missing values count
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Data Types:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
#
# Missing Values:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#SURVIVAL RATE ANALYSIS
#survival by gender
survival_sex = df.groupby("Sex")["Survived"].mean()
print("\nSurvival Rate by Sex:")
print(survival_sex)
survival_sex.plot(kind="bar")
plt.title("Survival Rate by Sex")
plt.ylabel("Survival Rate")
plt.show()
# Out:
# Survival Rate by Sex:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
#survival by passenger class
survival_class = df.groupby("Pclass")["Survived"].mean()
print("\nSurvival Rate by Class:")
print(survival_class)
survival_class.plot(kind="bar")
plt.title("Survival Rate by Passenger Class")
plt.ylabel("Survival Rate")
plt.show()
# Out:
# Survival Rate by Class:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
#survival by age buckets
# Create age groups
df["AgeGroup"] = pd.cut(
    df["Age"],
    bins=[0, 12, 18, 35, 60, 100],
    labels=["Child", "Teen", "Adult", "Middle Age", "Senior"]
)

survival_age = df.groupby("AgeGroup")["Survived"].mean()
print("\nSurvival Rate by Age Group:")
print(survival_age)
survival_age.plot(kind="bar")
plt.title("Survival Rate by Age Group")
plt.ylabel("Survival Rate")
plt.show()
# Out:
# Survival Rate by Age Group:
# AgeGroup
# Child         0.579710
# Teen          0.428571
# Adult         0.382682
# Middle Age    0.400000
# Senior        0.227273
# Name: Survived, dtype: float64
# /tmp/ipython-input-3745511674.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   survival_age = df.groupby("AgeGroup")["Survived"].mean()

# %%
#age distribution by survival
sns.barplot(x="Survived", y="Age", data=df)
plt.title("Age Distribution by Survival (Bar Plot)")
plt.show()
sns.boxplot(x="Survived", y="Age", data=df)
plt.title("Age Distribution by Survival (Box Plot)")
plt.show()
sns.violinplot(x="Survived", y="Age", data=df)
plt.title("Age Distribution by Survival (Violin Plot)")
plt.show()

# %%
print("\nINSIGHTS:")
print("1. Females had a much higher survival rate than males.")
print("2. First-class passengers survived more than second and third class.")
print("3. Children had better survival chances compared to adults.")
print("4. Survival chances decreased with lower passenger class.")
print("5. Younger passengers generally had higher survival probability.")
# Out:
# INSIGHTS:
# 1. Females had a much higher survival rate than males.
# 2. First-class passengers survived more than second and third class.
# 3. Children had better survival chances compared to adults.
# 4. Survival chances decreased with lower passenger class.
# 5. Younger passengers generally had higher survival probability.
