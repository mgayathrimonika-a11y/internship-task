# %%
import pandas as pd

# %%
data = pd.read_csv("sample_data_100rows.csv")

# %%
# INSPECT THE HEAD OF THE DATA
data.head()
# Out:
#      Name  Age     City  Salary
# 0   Rahul   20  Chennai   57133
# 1    Ritu   28     Pune   70397
# 2   Arjun   43    Delhi   70753
# 3  Manish   42  Chennai   67545
# 4   Priya   55   Mumbai   37182

# %%
# INSPECT THE TAIL OF THE DATA
data.tail(10)
# Out:
#       Name  Age       City  Salary
# 90   Rahul   36     Mumbai   67880
# 91  Manish   21  Hyderabad   36561
# 92   Kiran   35    Chennai   50489
# 93   Meera   33      Delhi   74531
# 94   Kavya   31     Jaipur   27499
# 95   Kiran   27  Bangalore   53480
# 96   Rohit   46     Mumbai   26136
# 97   Arjun   50       Pune   79790
# 98  Vikram   37       Pune   69643
# 99   Kavya   48     Jaipur   45919

# %%
#DATA TYPE
data.dtypes
# Out:
# Name      object
# Age        int64
# City      object
# Salary     int64
# dtype: object

# %%
#OVERVIEW
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    100 non-null    object
#  1   Age     100 non-null    int64
#  2   City    100 non-null    object
#  3   Salary  100 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 3.3+ KB

# %%
#SUMMARY STATISTICS
data.describe()
# Out:
#               Age        Salary
# count  100.000000    100.000000
# mean    37.280000  54359.680000
# std     10.614532  19633.837326
# min     20.000000  25557.000000
# 25%     28.750000  36373.250000
# 50%     37.000000  54055.000000
# 75%     46.250000  70790.500000
# max     55.000000  89906.000000

# %%
data["Salary"].mean()
# Out:
# np.float64(54359.68)

# %%
data["Salary"].sum()
# Out:
# np.int64(5435968)

# %%
data["Salary"].median()
# Out:
# 54055.0

# %%
data["Age"].min()
# Out:
# 20

# %%
data["Age"].max()
# Out:
# 55

# %%
data["Salary"].count()
# Out:
# np.int64(100)

# %%
#Filtering Rows
data_filtered = data[data["Age"] > 30]
print(data_filtered)
# Out:
#       Name  Age     City  Salary
# 2    Arjun   43    Delhi   70753
# 3   Manish   42  Chennai   67545
# 4    Priya   55   Mumbai   37182
# 6    Rahul   31    Delhi   49079
# 7     Amit   47  Chennai   70903
# ..     ...  ...      ...     ...
# 94   Kavya   31   Jaipur   27499
# 96   Rohit   46   Mumbai   26136
# 97   Arjun   50     Pune   79790
# 98  Vikram   37     Pune   69643
# 99   Kavya   48   Jaipur   45919
#
# [72 rows x 4 columns]

# %%
data_filtered = data[(data["Age"] > 30) & (data["City"] == "Chennai")]
print(data_filtered)

data_sorted = data.sort_values(by="Age", ascending=False)
print(data_sorted)
# Out:
#       Name  Age     City  Salary
# 3   Manish   42  Chennai   67545
# 7     Amit   47  Chennai   70903
# 10   Anita   51  Chennai   53695
# 24   Kiran   33  Chennai   86889
# 62  Sameer   32  Chennai   46269
# 64   Pooja   53  Chennai   37332
# 92   Kiran   35  Chennai   50489
#       Name  Age       City  Salary
# 4    Priya   55     Mumbai   37182
# 38  Vikram   55      Delhi   37198
# 56   Rahul   55      Delhi   28032
# 16  Sameer   54  Bangalore   25705
# 43  Sanjay   54     Mumbai   30455
# ..     ...  ...        ...     ...
# 57   Kavya   20    Chennai   70156
# 67   Divya   20    Chennai   32133
# 72   Priya   20       Pune   29888
# 69    Ritu   20     Jaipur   27061
# 88   Meera   20    Chennai   44497
#
# [100 rows x 4 columns]

# %%
subset = data[["Name", "Age", "Salary"]]
print(subset)
#Slice Rows
data.iloc[0:10]
data.loc[5:15, ["Name", "Salary"]]
# Out:
#       Name  Age  Salary
# 0    Rahul   20   57133
# 1     Ritu   28   70397
# 2    Arjun   43   70753
# 3   Manish   42   67545
# 4    Priya   55   37182
# ..     ...  ...     ...
# 95   Kiran   27   53480
# 96   Rohit   46   26136
# 97   Arjun   50   79790
# 98  Vikram   37   69643
# 99   Kavya   48   45919
#
# [100 rows x 3 columns]
#      Name  Salary
# 5   Pooja   25581
# 6   Rahul   49079
# 7    Amit   70903
# 8   Anita   77004
# 9   Arjun   36422
# 10  Anita   53695
# 11  Pooja   84803
# 12   Neha   73084
# 13  Meera   41638
# 14   Amit   40393
# 15   Neha   46909

# %%
#Save to CSV
data_filtered.to_csv("filtered.csv", index=False)
#Save to excel
data_filtered.to_excel("filtered.xlsx", index=False)
